# %%
import torch

def check_system():
  # system variables.
  cuda_available = torch.cuda.is_available()
  cuda_count = torch.cuda.device_count()

  # current device.
  curr_device = torch.cuda.current_device()
  device_name = torch.cuda.get_device_name(curr_device)
  properties = torch.cuda.get_device_properties(curr_device)

  print(f"Pythorch version : [{torch.__version__}]")
  print(f"CUDA available : {cuda_available}")
  print(f"GPU count : [{cuda_count}]")
  print(f"Primary device : [{device_name}]")
  print(f"Total Memory : [{properties.total_memory / 1024**2:.0f} MB]")
def main():
  check_system()

if __name__ == "__main__":
    main()
# Out:
# Pythorch version : [2.6.0+cu124]
# CUDA available : True
# GPU count : [1]
# Primary device : [Tesla T4]
# Total Memory : [14913 MB]
